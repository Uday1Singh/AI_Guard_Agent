# %% [markdown]
# ### Uday Singh (22B1262)
# ### Ankit Maurya (22B1266)

# %% [markdown]
# ### Github Link: https://github.com/Uday1Singh/AI_Guard_Agent/tree/master

# %%
pip install deepface opencv-python speechrecognition pyttsx3
# Out:
# Collecting deepface
#   Downloading deepface-0.0.95-py3-none-any.whl.metadata (35 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.10.4-py2.py3-none-any.whl.metadata (28 kB)
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (1.24.3)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (2.0.3)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (4.66.4)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (10.0.1)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (2.13.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from deepface) (2.13.1)
# Collecting Flask>=1.1.2 (from deepface)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting flask-cors>=4.0.1 (from deepface)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting retina-face>=0.0.14 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: typing-extensions in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from speechrecognition) (4.12.2)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.12-py3-none-any.whl.metadata (7.3 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from pyttsx3) (305.1)
# Requirement already satisfied: termcolor in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Collecting itsdangerous>=2.1.2 (from Flask>=1.1.2->deepface)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask>=1.1.2->deepface)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting blinker>=1.6.2 (from Flask>=1.1.2->deepface)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from Flask>=1.1.2->deepface) (6.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.27.1->deepface) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.27.1->deepface) (2023.11.17)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.16.0)
# Collecting typing-extensions (from speechrecognition)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.64.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: colorama in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=1.1.2->deepface) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.31.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\berse\anaconda3\envs\pytorch\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Downloading deepface-0.0.95-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.3 kB ? eta -:--:--
#    ---------------------------------------- 128.3/128.3 kB ? eta 0:00:00
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.0 MB 10.9 MB/s eta 0:00:04
#     --------------------------------------- 0.6/39.0 MB 8.0 MB/s eta 0:00:05
#    - -------------------------------------- 1.2/39.0 MB 9.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.7/39.0 MB 10.1 MB/s eta 0:00:04
#    -- ------------------------------------- 2.3/39.0 MB 9.8 MB/s eta 0:00:04
#    --- ------------------------------------ 2.9/39.0 MB 10.4 MB/s eta 0:00:04
#    --- ------------------------------------ 3.4/39.0 MB 11.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.9/39.0 MB 10.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.6/39.0 MB 11.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.0/39.0 MB 11.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.7/39.0 MB 11.4 MB/s eta 0:00:03
#    ------ --------------------------------- 6.3/39.0 MB 11.5 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/39.0 MB 11.5 MB/s eta 0:00:03
#    ------- -------------------------------- 7.4/39.0 MB 11.3 MB/s eta 0:00:03
#    ------- -------------------------------- 7.6/39.0 MB 11.0 MB/s eta 0:00:03
#    ------- -------------------------------- 7.7/39.0 MB 10.5 MB/s eta 0:00:03
#    ------- -------------------------------- 7.7/39.0 MB 10.5 MB/s eta 0:00:03
#    -------- ------------------------------- 8.2/39.0 MB 9.7 MB/s eta 0:00:04
#    -------- ------------------------------- 8.2/39.0 MB 9.4 MB/s eta 0:00:04
#    -------- ------------------------------- 8.7/39.0 MB 9.2 MB/s eta 0:00:04
#    --------- ------------------------------ 8.9/39.0 MB 9.0 MB/s eta 0:00:04
MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 11.1 MB/s eta 0:00:00
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Downloading comtypes-1.4.12-py3-none-any.whl (253 kB)
#    ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#    ---------------------------------------- 253.7/253.7 kB 7.9 MB/s eta 0:00:00
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#    ---------------------------------------- 98.2/98.2 kB 5.9 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: typing-extensions, pypiwin32, opencv-python, itsdangerous, gunicorn, fire, comtypes, click, blinker, speechrecognition, pyttsx3, mtcnn, Flask, gdown, flask-cors, retina-face, deepface
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# Successfully installed Flask-3.0.3 blinker-1.8.2 click-8.1.8 comtypes-1.4.12 deepface-0.0.95 fire-0.7.1 flask-cors-5.0.0 gdown-5.2.0 gunicorn-23.0.0 itsdangerous-2.2.0 mtcnn-0.1.1 opencv-python-4.12.0.88 pypiwin32-223 pyttsx3-2.99 retina-face-0.0.17 speechrecognition-3.10.4 typing-extensions-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.1.2 requires fsspec, which is not installed.
# sqlalchemy 2.0.34 requires typing-extensions>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.

# %%
pip install pyaudio
# Out:
# Collecting pyaudioNote: you may need to restart the kernel to use updated packages.
#
#   Downloading PyAudio-0.2.14-cp38-cp38-win_amd64.whl.metadata (2.7 kB)
# Downloading PyAudio-0.2.14-cp38-cp38-win_amd64.whl (164 kB)
#    ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/164.1 kB ? eta -:--:--
#    ---- ---------------------------------- 20.5/164.1 kB 217.9 kB/s eta 0:00:01
#    ---- ---------------------------------- 20.5/164.1 kB 217.9 kB/s eta 0:00:01
#    --------- ----------------------------- 41.0/164.1 kB 217.9 kB/s eta 0:00:01
#    -------------- ------------------------ 61.4/164.1 kB 251.0 kB/s eta 0:00:01
#    -------------------------------------  163.8/164.1 kB 653.6 kB/s eta 0:00:01
#    -------------------------------------- 164.1/164.1 kB 578.3 kB/s eta 0:00:00
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.14

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
import os
import cv2
import numpy as np
from deepface import DeepFace

MODEL = "Facenet512"
DETECTOR = "retinaface"

# ------------------------------
# Generate augmented images
# ------------------------------
def augment_image(img):
    h, w = img.shape[:2]
    augmented = [img]

    # Flip horizontally
    augmented.append(cv2.flip(img, 1))

    # Brightness changes
    for alpha in [0.8, 1.2]:  # darker, brighter
        bright = cv2.convertScaleAbs(img, alpha=alpha, beta=0)
        augmented.append(bright)

    # Rotations
    for angle in [-10, 10]:
        M = cv2.getRotationMatrix2D((w//2, h//2), angle, 1.0)
        rotated = cv2.warpAffine(img, M, (w, h))
        augmented.append(rotated)

    # Scaling (zoom in/out)
    for scale in [0.9, 1.1]:
        resized = cv2.resize(img, None, fx=scale, fy=scale, interpolation=cv2.INTER_LINEAR)
        # center crop back to original size
        y1 = max(0, (resized.shape[0] - h)//2)
        x1 = max(0, (resized.shape[1] - w)//2)
        cropped = resized[y1:y1+h, x1:x1+w]
        cropped = cv2.resize(cropped, (w, h))
        augmented.append(cropped)

    return augmented


# ------------------------------
# Compute embedding for an image
# ------------------------------
def get_embedding_from_image(img):
    rep = DeepFace.represent(
        img_path=img,
        model_name=MODEL,
        detector_backend=DETECTOR,
        enforce_detection=False
    )
    emb = np.array(rep[0]["embedding"])
    return emb / np.linalg.norm(emb)


def get_embedding(img_path):
    img = cv2.imread(img_path)
    if img is None:
        raise ValueError(f"Cannot read {img_path}")

    augmented_images = augment_image(img)
    embeddings = []

    for aug in augmented_images:
        try:
            emb = get_embedding_from_image(aug)
            embeddings.append(emb)
        except Exception as e:
            print(f"⚠️ Augmentation skipped: {e}")
            continue

    # Average embedding across all augmentations
    if len(embeddings) == 0:
        raise ValueError("No valid embeddings generated.")
    mean_embedding = np.mean(embeddings, axis=0)
    return mean_embedding / np.linalg.norm(mean_embedding)


# ------------------------------
# Compute embeddings for all images
# ------------------------------
def compute_all(folder):
    embeddings, names = [], []
    for f in os.listdir(folder):
        if f.lower().endswith((".jpg", ".jpeg", ".png", ".webp")):
            path = os.path.join(folder, f)
            try:
                emb = get_embedding(path)
                embeddings.append(emb)
                names.append(f)
                print(f"✅ {f} processed with augmentation.")
            except Exception as e:
                print(f"⚠️ {f} skipped: {e}")
    return np.array(embeddings), names


# ------------------------------
# Main
# ------------------------------
if __name__ == "__main__":
    trusted_embeddings, _ = compute_all("trusted_faces")
    random_embeddings, _ = compute_all("random_faces")

    np.savez("embeddings.npz", trusted=trusted_embeddings, random=random_embeddings)
    print("✅ Embeddings saved to embeddings.npz")
# Out:
# ✅ Uday_Singh.jpg processed with augmentation.
# ✅ 1.jpg processed with augmentation.
# ✅ 2.jpg processed with augmentation.
# ✅ 3.jpg processed with augmentation.
# ✅ 4.webp processed with augmentation.
# ✅ 5.webp processed with augmentation.
# ✅ 6.jpeg processed with augmentation.
# ✅ Embeddings saved to embeddings.npz

# %%
trusted_embeddings
# Out:
# array([[ 4.28407786e-02,  9.43758612e-02,  6.14525407e-03,
#          2.22708325e-02,  3.98800564e-02, -1.84416585e-02,
#          4.60061828e-02,  3.10852949e-03,  3.24337335e-02,
#         -2.53494142e-02, -1.30162903e-02, -2.92052044e-02,
#         -8.23839804e-02,  4.81789380e-02,  6.19577349e-02,
#         -3.23829688e-02,  3.92418648e-02,  6.64720354e-02,
#         -2.20090428e-02,  2.63145139e-03, -8.79192306e-02,
#         -1.29556966e-02,  4.39562625e-02, -2.71157954e-02,
#         -1.21709071e-02, -2.27222263e-02, -4.69552221e-03,
#         -6.93889172e-02,  3.33963229e-03, -2.03577709e-02,
#         -3.61025960e-02,  2.19211477e-02, -9.23424928e-03,
#         -9.28284532e-02, -3.00911754e-02, -3.67249204e-02,
#         -3.58824578e-02,  9.48737968e-02,  8.72722695e-02,
#          6.35344850e-02,  3.18511745e-02,  1.00499105e-01,
#          2.20754053e-02,  5.82580595e-03, -4.72823275e-02,
#          2.48840393e-02,  5.09606849e-02,  2.47353821e-03,
#          6.77507542e-02,  4.65096509e-02,  9.07840907e-03,
#         -1.99677957e-02,  3.88732341e-03, -7.85000461e-02,
#         -1.85542444e-02,  3.50920054e-03,  1.09490087e-02,
#          4.16865211e-02,  9.55157525e-04, -1.11155688e-02,
#          1.41521820e-02,  2.64159253e-02,  3.16334512e-02,
#          2.57831505e-02,  5.19282688e-03,  7.72675013e-02,
#         -4.67893667e-02,  4.68710385e-02,  4.82725258e-02,
#         -2.29954923e-02, -2.59752200e-03, -7.27093631e-02,
#         -4.94307830e-02, -1.22333481e-02,  1.77779917e-02,
#         -5.83691208e-02, -3.29668129e-02,  1.67573177e-02,
#          2.19798808e-02, -2.39458088e-02, -1.83443974e-02,
#         -5.87883384e-03, -2.35998003e-02,  5.85001401e-02,
#         -3.22076985e-03,  1.71886240e-02,  2.61175651e-03,
#          3.71848669e-02, -1.54019043e-02, -7.62314308e-02,
#          1.52548484e-03, -2.63265777e-02]])

# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in c:\users\pashu\appdata\roaming\python\python313\site-packages (1.97.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\pashu\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\pashu\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: colorama in c:\users\pashu\appdata\roaming\python\python313\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pygame
#   Using cached pygame-2.6.1-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp313-cp313-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/10.6 MB 11.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/10.6 MB 10.6 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/10.6 MB 9.0 MB/s eta 0:00:01
#    ------------------------- -------------- 6.8/10.6 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 8.2 MB/s  0:00:01
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-genai
#   Using cached google_genai-1.45.0-py3-none-any.whl.metadata (45 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-genai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\pashu\appdata\roaming\python\python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\pashu\appdata\roaming\python\python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\pashu\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Downloading google_genai-1.45.0-py3-none-any.whl (238 kB)
# Downloading google_genai-1.45.0-py3-none-any.whl (238 kB)
# Downloading google_genai-1.45.0-py3-none-any.whl (238 kB)
# Installing collected packages: google-genai
# Successfully installed google-genai-1.45.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (0 bytes/238 kB, attempt 1)
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (0 bytes/238 kB, attempt 2)

# %%
import cv2
import numpy as np
import time
import datetime
import os
import speech_recognition as sr
import threading
import pygame
from deepface import DeepFace
import difflib
from gtts import gTTS
import tempfile
from google import genai

# ========== GEMINI API KEY ==========

def query_gemini(prompt):
    # Initialize GenAI client with your API key
    client = genai.Client(api_key="AIzaSyDIFttbAx7aMskpQtroxB7SsMRBpL15Q_Y")

    # Query Gemini 2.5 Pro
    response = client.models.generate_content(
        model="gemini-2.5-pro",
        contents="Generate a very short, polite but firm verbal warning for an unknown intruder detected in a private room. Give only what to say as it will be read aloud as it is."
    )
    return response.text

# Initialize pygame mixer once
pygame.mixer.init()
buzzer_sound = pygame.mixer.Sound("buzzer.mp3")  # Ensure this mp3 file exists locally
buzzer_playing = False

def start_buzzer():
    global buzzer_playing
    if not buzzer_playing:
        buzzer_playing = True
        buzzer_sound.play(-1)

def stop_buzzer():
    global buzzer_playing
    if buzzer_playing:
        buzzer_sound.stop()
        buzzer_playing = False

def speak(text):
    def _play_audio():
        with tempfile.NamedTemporaryFile(delete=False, suffix=".mp3") as tmp:
            filename = tmp.name
        tts = gTTS(text=text, lang='en')
        tts.save(filename)
        pygame.mixer.music.load(filename)
        pygame.mixer.music.play()
        while pygame.mixer.music.get_busy():
            pygame.time.Clock().tick(10)
        for _ in range(5):
            try:
                os.remove(filename)
                break
            except PermissionError:
                time.sleep(0.1)
    threading.Thread(target=_play_audio, daemon=True).start()

def cosine_sim(a, b):
    return np.dot(a, b) / (np.linalg.norm(a)*np.linalg.norm(b))

# Load embeddings and calculate threshold
data = np.load("embeddings.npz")
trusted_embeddings = data["trusted"]
random_embeddings = data["random"]
trusted_centroid = np.mean(trusted_embeddings, axis=0)
trusted_centroid /= np.linalg.norm(trusted_centroid)
trusted_sims = [cosine_sim(trusted_centroid, t) for t in trusted_embeddings]
random_sims = [cosine_sim(trusted_centroid, r) for r in random_embeddings]
THRESHOLD = (np.mean(trusted_sims) + np.mean(random_sims))/2
print(f"🔹 Auto-calibrated threshold: {THRESHOLD:.3f}")

def wait_for_activation():
    recognizer = sr.Recognizer()
    mic = sr.Microphone()
    target_phrase = "guard my room"
    print("🎙️ Say 'Guard my room' to activate.")
    speak("Say guard my room to activate.")
    while True:
        with mic as source:
            recognizer.adjust_for_ambient_noise(source)
            try:
                audio = recognizer.listen(source, timeout=5)
                command = recognizer.recognize_google(audio).lower()
                print(f"🗣️ Heard: {command}")
                if difflib.get_close_matches(command, [target_phrase], n=1, cutoff=0.6):
                    speak("Guarding mode activated.")
                    print("🛡️ Guarding mode ON")
                    return
                else:
                    print("🤔 Didn't match activation phrase.")
            except (sr.WaitTimeoutError, sr.UnknownValueError):
                pass
            except Exception as e:
                print(f"⚠️ Recognizer error: {e}")

def start_guarding():
    cap = cv2.VideoCapture(0)
    frame_count = 0
    unknown_start_time = None
    last_unknown_save = 0
    SAVE_COOLDOWN = 10
    UNKNOWN_ALERT_TIME = 5
    unknown_dir = "unknown_faces"
    os.makedirs(unknown_dir, exist_ok=True)

    print("🎥 Camera active. Press 'q' to quit.")

    while True:
        ret, frame = cap.read()
        if not ret:
            continue

        frame_count += 1
        if frame_count % 3 != 0:
            continue

        frame_resized = cv2.resize(frame, (480, 360))
        try:
            detections = DeepFace.extract_faces(
                img_path=frame_resized,
                detector_backend="opencv",
                enforce_detection=False
            )
        except Exception as e:
            print(f"⚠️ Face extraction error: {e}")
            detections = []

        intruder_found = False

        for det in detections:
            face = det.get("face")
            area = det.get("facial_area", {})
            if face is None or not area:
                continue

            x, y, w, h = int(area.get("x", 0)), int(area.get("y", 0)), int(area.get("w", 0)), int(area.get("h", 0))

            try:
                rep = DeepFace.represent(
                    img_path=face,
                    model_name="Facenet512",
                    detector_backend="skip",
                    enforce_detection=False
                )
                emb = np.array(rep[0]["embedding"])
                emb /= np.linalg.norm(emb)
            except Exception as e:
                print(f"⚠️ Embedding extraction error: {e}")
                continue

            sim = cosine_sim(emb, trusted_centroid)
            now = time.time()

            if sim > THRESHOLD:
                label = f"TRUSTED ({sim:.2f})"
                color = (0, 255, 0)
                unknown_start_time = None
                stop_buzzer()
            else:
                label = f"UNKNOWN ({sim:.2f})"
                color = (0, 0, 255)
                intruder_found = True
                if unknown_start_time is None:
                    unknown_start_time = now
                elif now - unknown_start_time > UNKNOWN_ALERT_TIME:
                    if now - last_unknown_save > SAVE_COOLDOWN:
                        ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
                        fname = os.path.join(unknown_dir, f"unknown_{ts}.jpg")

                        # Convert face to BGR uint8 for saving
                        face_bgr = cv2.cvtColor((face * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
                        cv2.imwrite(fname, face_bgr)
                        print(f"💾 Unknown face saved: {fname}")

                        if 0:
                            warning_msg = query_gemini("Generate a very short, polite but firm verbal warning for an unknown intruder detected in a private room. Give only what to say as it will be read aloud as it is.")
                        else:
                            warning_msg = "Warning! You are not authorized to be here. Please leave immediately. Owner has been notified and you are being recorded."
                        print("🤖 LLM warning:", warning_msg)

                        speak(warning_msg)
                        start_buzzer()
                        last_unknown_save = now

            # Draw bounding box and label on original frame (resized, so coordinates must fit)
            cv2.rectangle(frame_resized, (x, y), (x + w, y + h), color, 2)
            cv2.putText(frame_resized, label, (x, max(y - 10, 0)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

        if not intruder_found:
            unknown_start_time = None
            stop_buzzer()

        cv2.imshow("Face Verification", frame_resized)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    stop_buzzer()

if __name__ == "__main__":
    wait_for_activation()
    start_guarding()
# Out:
# 🔹 Auto-calibrated threshold: 0.603
# 🎙️ Say 'Guard my room' to activate.
# 🗣️ Heard: guard my room
# 🛡️ Guarding mode ON
# 🎥 Camera active. Press 'q' to quit.
# 💾 Unknown face saved: unknown_faces\unknown_20251018_230952.jpg
# 🤖 LLM warning: Warning! You are not authorized to be here. Please leave immediately. Owner has been notified and you are being recorded.
# 💾 Unknown face saved: unknown_faces\unknown_20251018_231002.jpg
# 🤖 LLM warning: Warning! You are not authorized to be here. Please leave immediately. Owner has been notified and you are being recorded.
